# %% [markdown]
# ## Census Income project
#
# ### Project Description
#
# This data was extracted from the 1994 Census bureau database by Ronny Kohavi and Barry Becker (Data Mining and Visualization, Silicon Graphics). A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1) && (HRSWK>0)). The prediction task is to determine whether a person makes over $50K a year.
#
# **Description of fnlwgt (final weight):**
#
# The weights on the Current Population Survey (CPS) files are controlled to independent estimates of the civilian non-institutional population of the US. These are prepared monthly for us by Population Division here at the Census Bureau. We use 3 sets of controls. These are:
#
# * A single cell estimate of the population 16+ for each state.
#
# * Controls for Hispanic Origin by age and sex.
#
# * Controls by Race, age and sex.
#
# We use all three sets of controls in our weighting program and "rake" through them 6 times so that by the end we come back to all the controls we used. The term estimate refers to population totals derived from CPS by creating "weighted tallies" of any specified socio-economic characteristics of the population. People with similar demographic characteristics should have similar weights. There is one important caveat to remember about this statement. That is that since the CPS sample is actually a collection of 51 state samples, each with its own probability of selection, the statement only applies within state.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings('ignore')
import scipy

# %% [markdown]
# ### Importing Dataset

# %%
df=pd.read_csv('census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital_gain  Capital_loss  Hours_per_week  Native_country  \
# 0         Male             0             0              13   United-States
# 1         Male             0             0              40   United-States
# 2         Male             0             0              40   United-States
# 3       Female             0             0              40            Cuba
# 4       Female             0             0              40   United-States
# ...        ...           ...           ...             ...             ...
# 32555   Female             0             0              38   United-States
# 32556     Male             0             0              40   United-States
# 32557   Female             0             0              40   United-States
# 32558     Male             0             0              20   United-States
# 32559   Female         15024             0              40   United-States
#
#        Income
# 0       <=50K
# 1       <=50K
# 2       <=50K
# 3       <=50K
# 4       <=50K
# ...       ...
# 32555   <=50K
# 32556    >50K
# 32557   <=50K
# 32558   <=50K
# 32559    >50K
#
# [32560 rows x 15 columns]

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# This dataset contains 32560 rows and 15 columns

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0             0             0              13   United-States   <=50K
# 1             0             0              40   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40            Cuba   <=50K
# 4             0             0              40   United-States   <=50K

# %%
df.tail()
# Out:
#        Age      Workclass  Fnlwgt    Education  Education_num  \
# 32555   27        Private  257302   Assoc-acdm             12
# 32556   40        Private  154374      HS-grad              9
# 32557   58        Private  151910      HS-grad              9
# 32558   22        Private  201490      HS-grad              9
# 32559   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation Relationship    Race      Sex  \
# 32555   Married-civ-spouse        Tech-support         Wife   White   Female
# 32556   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 32557              Widowed        Adm-clerical    Unmarried   White   Female
# 32558        Never-married        Adm-clerical    Own-child   White     Male
# 32559   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 32555             0             0              38   United-States   <=50K
# 32556             0             0              40   United-States    >50K
# 32557             0             0              40   United-States   <=50K
# 32558             0             0              20   United-States   <=50K
# 32559         15024             0              40   United-States    >50K

# %%
df.sample()
# Out:
#        Age Workclass  Fnlwgt Education  Education_num       Marital_status  \
# 17624   41   Private  307468   HS-grad              9   Married-civ-spouse
#
#               Occupation Relationship    Race    Sex  Capital_gain  \
# 17624   Transport-moving      Husband   White   Male             0
#
#        Capital_loss  Hours_per_week  Native_country  Income
# 17624             0              50   United-States   <=50K

# %% [markdown]
# ### Dropping unwanted data

# %%
#Checking the value count of Capital_loss column
df["Capital_loss"].value_counts()
# Out:
# 0       31041
# 1902      202
# 1977      168
# 1887      159
# 1848       51
#         ...
# 2080        1
# 1539        1
# 1844        1
# 2489        1
# 1411        1
# Name: Capital_loss, Length: 92, dtype: int64

# %%
(31041/32560*100)
# Out:
# 95.33476658476658

# %% [markdown]
# In this perticular Capital_loss column there are 95% zero values so we will drop this column. because it is not playing an imp. role

# %%
#Droping Capital_gain column
df = df.drop(["Capital_loss"],axis=1)

# %%
#Checking the value count of Capital_loss column
df["Capital_gain"].value_counts()
# Out:
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 1111         1
# 2538         1
# 22040        1
# 4931         1
# 5060         1
# Name: Capital_gain, Length: 119, dtype: int64

# %%
(29849/32560*100)
# Out:
# 91.67383292383292

# %% [markdown]
# In this perticular Capital_gain column there are 92% zero values so we will drop this column. it is not playing an imp. role.

# %%
#Droping Capital_gain column
df = df.drop(["Capital_gain"],axis=1)

# %%
df.shape
# Out:
# (32560, 13)

# %% [markdown]
# # Exploratory Data Analysis[EDA]

# %%
df.columns.to_list()
# Out:
# ['Age',
#  'Workclass',
#  'Fnlwgt',
#  'Education',
#  'Education_num',
#  'Marital_status',
#  'Occupation',
#  'Relationship',
#  'Race',
#  'Sex',
#  'Hours_per_week',
#  'Native_country',
#  'Income']

# %% [markdown]
# **Checking for the various data types present in the dataset:**

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# ### Checking for duplicate values

# %%
df.duplicated().sum()
# Out:
# 26

# %% [markdown]
# As we can see here that duplicate values are present in the dataset.

# %% [markdown]
# **Removing duplicate values from the dataset:**

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# As we can see here that all the duplicated values are removed from the dataset

# %% [markdown]
# ### Checking for white space

# %%
# Check for white spaces
has_white_spaces = ' ' in df
print(has_white_spaces)
# Out:
# False

# %% [markdown]
# As we can see here that no white space is present in the dataset.

# %% [markdown]
# ### Checking for the prescence of various symbol

# %%
df.isin([' ?']).sum()
# Out:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_num        0
# Marital_status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Hours_per_week       0
# Native_country     582
# Income               0
# dtype: int64

# %% [markdown]
# Here we can see that symbol `?` is present in columns[`workclass`, `occupation`, `native_country`] and we have to treat it
#
# Since this columns are categorical columns we will use mode method to remove the `?` symbol from the data

# %%
df["Workclass"].mode()
# Out:
# 0     Private
# Name: Workclass, dtype: object

# %% [markdown]
# mode of `workclass` column is private

# %%
df["Occupation"].mode()
# Out:
# 0     Prof-specialty
# Name: Occupation, dtype: object

# %% [markdown]
# Mode of `Occupation` column is Prof-specialty

# %%
df["Native_country"].mode()
# Out:
# 0     United-States
# Name: Native_country, dtype: object

# %% [markdown]
# Mode of `Native_country` is United-States

# %%
df['Workclass'] = df.Workclass.str.replace('?', 'Private')
df['Occupation'] = df.Occupation.str.replace('?', 'Prof-specialty')
df['Native_country'] = df.Native_country.str.replace('?', 'United-States')

# %%
df.isin([' ?']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# As we can see here that symbol `?` removed from the data

# %%
df.isin(['@']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# symbol `@` is not present in the dataset

# %%
df.isin(['#']).sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# symbol `#` is not present in the dataset

# %% [markdown]
# Symbol `#` is not present in the dataset

# %% [markdown]
# **Checking for the null values**

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# We can say that no null values are present in the dataset

# %% [markdown]
# **heatmap visualization for null values:**

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# After visualization with heatmap we can say that there are no null values present in the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32534 entries, 0 to 32559
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32534 non-null  int64
#  1   Workclass       32534 non-null  object
#  2   Fnlwgt          32534 non-null  int64
#  3   Education       32534 non-null  object
#  4   Education_num   32534 non-null  int64
#  5   Marital_status  32534 non-null  object
#  6   Occupation      32534 non-null  object
#  7   Relationship    32534 non-null  object
#  8   Race            32534 non-null  object
#  9   Sex             32534 non-null  object
#  10  Hours_per_week  32534 non-null  int64
#  11  Native_country  32534 non-null  object
#  12  Income          32534 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 3.5+ MB

# %% [markdown]
# It is showing a general information about the dataset like name of the columns present in the dataset total non null values present in the dataset types of data present in the dataset memory occupied by the dataset.

# %%
#Checking unique values of each column
df.nunique()
# Out:
# Age                  73
# Workclass             8
# Fnlwgt            21647
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           14
# Relationship          6
# Race                  5
# Sex                   2
# Hours_per_week       94
# Native_country       41
# Income                2
# dtype: int64

# %%
#Checking number of unique values in target column
df['Income'].nunique()
# Out:
# 2

# %%
#Checking unique values of target column
df['Income'].unique()
# Out:
# array([' <=50K', ' >50K'], dtype=object)

# %% [markdown]
# There are only two unique counts in the target column so it's a binary classification problem.

# %% [markdown]
# **Statistical Analysis of Dataset**

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Hours_per_week
# count  32534.000000  3.253400e+04   32534.000000    32534.000000
# mean      38.586433  1.897854e+05      10.081761       40.441108
# std       13.638097  1.055592e+05       2.571694       12.346714
# min       17.000000  1.228500e+04       1.000000        1.000000
# 25%       28.000000  1.178285e+05       9.000000       40.000000
# 50%       37.000000  1.783560e+05      10.000000       40.000000
# 75%       48.000000  2.369938e+05      12.000000       45.000000
# max       90.000000  1.484705e+06      16.000000       99.000000

# %% [markdown]
# **Observation:**
#
# * count for each of the columns is same which means that there are no nul values present in the dataset.
#
# * Mean is greater than median which means that skewness is present in the dataset, and the data is skewed to the right.
#
# * There is a huge difference between 75th percentile and max values so we can say that outliers are present in the dataset.
#
# * We can also observe std., min., 25th, 50th, 75th, and max values for each of the columns.

# %% [markdown]
# ### Separating categorical column & Numerical column

# %% [markdown]
# **categorical columns:**

# %%
# Separating categorical columns
categorical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_columns.append(i)
print(categorical_columns)
# Out:
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %% [markdown]
# **Numerical columns:**

# %%
# Separating numerical columns
numerical_columns=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_columns.append(i)
print(numerical_columns)
# Out:
# ['Age', 'Fnlwgt', 'Education_num', 'Hours_per_week']

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# ### Univarient Analysis

# %%
sns.distplot(df['Age'])
plt.title('Age')
plt.show()

# %% [markdown]
# Distribution of Age column which is showing maximum value in range between 20 to 60

# %%
sns.distplot(df['Fnlwgt'])
plt.title('Fnlwgt')
plt.show()

# %% [markdown]
# Distribution of Fnlwgt (final weight) column which is showing maximum value at 0.2

# %%
sns.distplot(df['Education_num'])
plt.title('Education_num')
plt.show()

# %%
sns.distplot(df['Hours_per_week'])
plt.title('Hours_per_week')
plt.show()

# %% [markdown]
# Distribution of Hours_per_week column with max value range between 40-50

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Workclass'])
plt.title('Workclass')
plt.show()

df.value_counts('Workclass')
# Out:
# Workclass
#  Private             24507
#  Self-emp-not-inc     2540
#  Local-gov            2093
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# dtype: int64

# %% [markdown]
# In workclass column private sector is contributing highest and never work and without pay contributing lowest

# %%
plt.figure(figsize=(15,10))
plt.pie(df['Workclass'].value_counts().values,labels=df['Workclass'].value_counts().index,autopct='%1.2f%%')
plt.title('Workclass')
plt.show()

# %% [markdown]
# Here we can see the pie chart distribution of workclass columns and private sector has highest contribution with 75.33%

# %%
plt.figure(figsize=(20,15))
sns.countplot(df['Education'])
plt.title('Education')
plt.show()

df.value_counts('Education')
# Out:
# Education
#  HS-grad         10493
#  Some-college     7281
#  Bachelors        5352
#  Masters          1722
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           645
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           332
#  1st-4th           166
#  Preschool          50
# dtype: int64

# %% [markdown]
# In education column Hs-grad value is highest and preschool value is lowest

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Marital_status'])
plt.title('Marital_status')
plt.show()

df.value_counts('Marital_status')
# Out:
# Marital_status
#  Married-civ-spouse       14969
#  Never-married            10665
#  Divorced                  4441
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# dtype: int64

# %% [markdown]
# In marital_status column Married-civ-spouse has highest value and Married-AF-spouse has lowest value

# %%
plt.figure(figsize=(25,10))
sns.countplot(df['Occupation'])
plt.title('Occupation')
plt.show()


df.value_counts('Occupation')
# Out:
# Occupation
#  Prof-specialty       5979
#  Craft-repair         4094
#  Exec-managerial      4065
#  Adm-clerical         3767
#  Sales                3650
#  Other-service        3290
#  Machine-op-inspct    1999
#  Transport-moving     1597
#  Handlers-cleaners    1369
#  Farming-fishing       992
#  Tech-support          927
#  Protective-serv       649
#  Priv-house-serv       147
#  Armed-Forces            9
# dtype: int64

# %% [markdown]
# In occupation column Prof-specialty has highest value and Armed-Forces has lowest value.

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Relationship'])
plt.title('Relationship')
plt.show()



df.value_counts('Relationship')
# Out:
# Relationship
#  Husband           13186
#  Not-in-family      8291
#  Own-child          5063
#  Unmarried          3445
#  Wife               1568
#  Other-relative      981
# dtype: int64

# %% [markdown]
# In Relationship column husband has highest value and Other-relative has lowest value.

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Race'])
plt.title('Race')
plt.show()



df.value_counts('Race')
# Out:
# Race
#  White                 27792
#  Black                  3122
#  Asian-Pac-Islander     1038
#  Amer-Indian-Eskimo      311
#  Other                   271
# dtype: int64

# %% [markdown]
# In Race column white has highest value and other has lowest value.

# %%
labels='White','Black','Asian-Pac-Islander','Amer-Indian-Eskimo','Other'
fig, ax = plt.subplots(figsize=(8,6))
ax.pie(df['Race'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True,)
plt.title('Race')
plt.show()

# %% [markdown]
# White has highest value with 85.43% in Race column

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Sex'])
plt.title('Sex')
plt.show()


df.value_counts('Sex')
# Out:
# Sex
#  Male      21773
#  Female    10761
# dtype: int64

# %% [markdown]
# In sex column male has highest value and female has lowest value.

# %%
labels='Male','Female'
fig, ax = plt.subplots(figsize=(8,6))
ax.pie(df['Sex'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True,)
plt.show()

# %% [markdown]
# Male has high value with 66.92% and Female has 33.08% in Sex column

# %%
plt.figure(figsize=(20,12))
sns.countplot(df['Native_country'])
plt.xticks(rotation=45, fontsize=8)
plt.title('Native_country')
plt.show()


df.value_counts('Native_country')
# Out:
# Native_country
#  United-States                 29732
#  Mexico                          639
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        62
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
#  Nicaragua                        34
#  Peru                             31
#  Greece                           29
#  France                           29
#  Ecuador                          28
#  Ireland                          24
#  Hong                             20
#  Trinadad&Tobago                  19
#  Cambodia                         19
#  Laos                             18
#  Thailand                         18
#  Yugoslavia                       16
#  Outlying-US(Guam-USVI-etc)       14
#  Hungary                          13
#  Honduras                         13
#  Scotland                         12
#  Holand-Netherlands                1
# dtype: int64

# %% [markdown]
# In Native_country column United-States has highest value and Holand-Netherlands has lowest value.

# %%
plt.figure(figsize=(12,8))
sns.countplot(df['Income'])
plt.title('Income')
plt.show()


df.value_counts('Income')
# Out:
# Income
#  <=50K    24695
#  >50K      7839
# dtype: int64

# %% [markdown]
# In Income column people who earn less than equal to 50k is higher than people who earn greater than 50k

# %%
labels='<=50K','>50K'
fig, ax = plt.subplots(figsize=(8,6))
ax.pie(df['Income'].value_counts(), labels=labels, autopct='%1.2f%%', shadow=True,)
plt.show()

# %% [markdown]
# people with earning lesss than or equals to 50k are higher with 75.91% and people who earn greater than 50k are 24.09%

# %% [markdown]
# ### Bivarient Analysis

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Age'],hue=df['Income'])
plt.title('Age vs Income Distribution',fontdict={'fontsize':30})
plt.show()

# %% [markdown]
# More Peoples between 36 years to 47 years have earned more than 50K
#
# Peoples started to earn at age 17, from 17 to 41 majority earn below 50k

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Workclass'],hue='Income', data=df)
plt.title(' Distribution of Income across WorkClass',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# In every work class, most people are geeting income <50k, However self emploid peoples are able to earn more than >50k

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Education'],hue='Income', data=df)
plt.title(' Distribution of Income across Education',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# More persons in Doctorate and Prof-School qualified persons got more than >50K & others has earn <=50k.

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Education_num'],hue='Income', data=df)
plt.title(' Distribution of Income across Education_num',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# In Education_num column number 14,15,16 has earn more than 50k and rest of the number has earn <=50k

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Marital_status'],hue='Income', data=df)
plt.title(' Distribution of Income across Marital_status',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# In Marital_status columns in every case scenerio <=50k is higer than >50k

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Race'],hue='Income', data=df)
plt.title(' Distribution of Income across Race',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# In column Race <=50k is higher than >50k

# %%
plt.figure(figsize=(20,8))
sns.countplot(df['Sex'],hue='Income', data=df)
plt.title(' Distribution of Income Sex',fontdict={'fontsize':25})
plt.show()

# %% [markdown]
# In column sex in both male and female income which is <=50k is higer

# %%
#Comparision between features using line plot
plt.figure(figsize=[8,6])
plt.title('Comparision between Age and Education_num')
sns.lineplot(df['Age'],df['Education_num'],hue=df["Income"])
plt.show()

# %% [markdown]
# It looks very clear that as the education number is increasing chance of getting income >5ok is also increasing.And also as age is more means experience is more the chance of getting income more than 50k is also more.

# %%
# Checking income with Fnlwgt
sns.barplot(x='Income',y='Fnlwgt',data=df,palette='ch:.25')
plt.title('Income with Fnlwgt')
plt.show()

# %%
# Checking income with Capital_gain
sns.barplot(x='Income',y='Age',data=df,palette='Set2')
plt.title('Income with Age')
plt.show()

# %%
# Checking income with Capital_loss
sns.barplot(x='Income',y='Education_num',data=df,palette='Set2')
plt.title('Income with Education_num')
plt.show()

# %% [markdown]
# People with higher education_nun has income more than >50k

# %%
# Checking income with Hours_per_week
sns.barplot(x='Income',y='Hours_per_week',data=df,palette='ch:.25')
plt.title('Income with Hours_per_week')
plt.show()

# %% [markdown]
# with increase in hours per week income is also increasing

# %% [markdown]
# ### Multivarient Analysis

# %%
sns.pairplot(df)
plt.show()

# %%
sns.pairplot(df, hue='Income')
plt.show()

# %% [markdown]
# Here we can se the pairplot for the whole dataset with hue='Income'

# %% [markdown]
# ### Checking for outliers

# %% [markdown]
# We never check prescence of outliers from categorical columns and target variables & to check the prescence of outliers we use boxplot visualization.

# %%
for i in numerical_columns:
    df.boxplot(i)
    plt.show()

# %% [markdown]
# By visualizing with boxplot we can say that outliers are present in the dataset & we have to remove the outlies from the dataset

# %% [markdown]
# **Removing outliers using Z-Score method:**

# %%
#Removing outliers
from scipy.stats import zscore
z=np.abs(zscore(df[numerical_columns]))

z
# Out:
#             Age    Fnlwgt  Education_num  Hours_per_week
# 0      0.836901  1.008685       1.134771        2.222577
# 1      0.043000  0.244991       0.420648        0.035727
# 2      1.056877  0.425698       1.198357        0.035727
# 3      0.776252  1.407986       1.134771        0.035727
# 4      0.116325  0.898056       1.523626        0.035727
# ...         ...       ...            ...             ...
# 32555  0.849577  0.639619       0.745917        0.197716
# 32556  0.103650  0.335469       0.420648        0.035727
# 32557  1.423503  0.358812       0.420648        0.035727
# 32558  1.216203  0.110884       0.420648        1.655616
# 32559  0.983552  0.929745       0.420648        0.035727
#
# [32534 rows x 4 columns]

# %%
#threshold value =3
threshold=3

print(np.where(z>3))
# Out:
# (array([    9,    27,    36, ..., 32498, 32498, 32504], dtype=int64), array([3, 3, 1, ..., 0, 3, 3], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

df_new
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# 1                 Divorced   Handlers-cleaners   Not-in-family   White
# 2       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 3       Married-civ-spouse      Prof-specialty            Wife   Black
# 4       Married-civ-spouse     Exec-managerial            Wife   White
# ...                    ...                 ...             ...     ...
# 32555   Married-civ-spouse        Tech-support            Wife   White
# 32556   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32557              Widowed        Adm-clerical       Unmarried   White
# 32558        Never-married        Adm-clerical       Own-child   White
# 32559   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Hours_per_week  Native_country  Income
# 0         Male              13   United-States   <=50K
# 1         Male              40   United-States   <=50K
# 2         Male              40   United-States   <=50K
# 3       Female              40            Cuba   <=50K
# 4       Female              40   United-States   <=50K
# ...        ...             ...             ...     ...
# 32555   Female              38   United-States   <=50K
# 32556     Male              40   United-States    >50K
# 32557   Female              40   United-States   <=50K
# 32558     Male              20   United-States   <=50K
# 32559   Female              40   United-States    >50K
#
# [31440 rows x 13 columns]

# %%
df_new.shape
# Out:
# (31440, 13)

# %%
df.shape
# Out:
# (32534, 13)

# %%
#Checking dataloss
Dataloss = (((32536-29808)/32536)*100)
Dataloss
# Out:
# 8.384558642734202

# %% [markdown]
# As we can see here that dataloss percentage is less than 10% so we can further proceed with the data.

# %%
df=df_new

# %%
df.shape
# Out:
# (31440, 13)

# %% [markdown]
# ### Check for skewness

# %%
df.skew()
# Out:
# Age               0.472223
# Fnlwgt            0.635737
# Education_num    -0.159346
# Hours_per_week   -0.340669
# dtype: float64

# %% [markdown]
# Accpetable range for skewness is -0.5 to +0.5 and according to this we can say that skewness is not present in the dataset. we never remove skewness from target column and categorical columns.

# %%
for i in numerical_columns:
    sns.distplot(df[i])
    plt.show()

# %% [markdown]
# By visualizing with displot we can see that skewness is not present in the dataset.

# %% [markdown]
# ### Encoding the categorical columns using Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=lb.fit_transform(df[i].values)

# %%
df.head()
# Out:
#    Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0   50          5   83311          8             13               2
# 1   38          3  215646         10              9               0
# 2   53          3  234721          1              7               2
# 3   28          3  338409          8             13               2
# 4   37          3  284582         11             14               2
#
#    Occupation  Relationship  Race  Sex  Hours_per_week  Native_country  Income
# 0           3             0     4    1              13              38       0
# 1           5             1     4    1              40              38       0
# 2           5             0     2    1              40              38       0
# 3           9             5     2    0              40               4       0
# 4           3             5     4    0              40              38       0

# %% [markdown]
# ### Correlation between target variable and independent variables

# %%
cor=df.corr()
cor
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000   0.037965 -0.072984  -0.000228       0.053353
# Workclass       0.037965   1.000000 -0.020753   0.004607       0.003821
# Fnlwgt         -0.072984  -0.020753  1.000000  -0.024033      -0.035142
# Education      -0.000228   0.004607 -0.024033   1.000000       0.356011
# Education_num   0.053353   0.003821 -0.035142   0.356011       1.000000
# Marital_status -0.286091  -0.020561  0.028426  -0.039243      -0.065667
# Occupation     -0.001308   0.007597  0.002641  -0.041210       0.073799
# Relationship   -0.268032  -0.056797  0.006790  -0.015251      -0.102677
# Race            0.030675   0.046292 -0.011107   0.015569       0.030896
# Sex             0.091650   0.070081  0.028976  -0.024779       0.016800
# Hours_per_week  0.097064   0.030304 -0.014802   0.061926       0.160676
# Native_country -0.001026  -0.001616 -0.059368   0.068106       0.054546
# Income          0.248263   0.003509 -0.008028   0.077595       0.337713
#
#                 Marital_status  Occupation  Relationship      Race       Sex  \
# Age                  -0.286091   -0.001308     -0.268032  0.030675  0.091650
# Workclass            -0.020561    0.007597     -0.056797  0.046292  0.070081
# Fnlwgt                0.028426    0.002641      0.006790 -0.011107  0.028976
# Education            -0.039243   -0.041210     -0.015251  0.015569 -0.024779
# Education_num        -0.065667    0.073799     -0.102677  0.030896  0.016800
# Marital_status        1.000000    0.034469      0.185678 -0.067528 -0.127358
# Occupation            0.034469    1.000000     -0.037476 -0.004065  0.047958
# Relationship          0.185678   -0.037476      1.000000 -0.115155 -0.583027
# Race                 -0.067528   -0.004065     -0.115155  1.000000  0.088793
# Sex                  -0.127358    0.047958     -0.583027  0.088793  1.000000
# Hours_per_week       -0.197365   -0.019913     -0.263261  0.045423  0.238823
# Native_country       -0.017388   -0.003726     -0.010985  0.122124  0.002136
# Income               -0.198368    0.034469     -0.251538  0.072482  0.216675
#
#                 Hours_per_week  Native_country    Income
# Age                   0.097064       -0.001026  0.248263
# Workclass             0.030304       -0.001616  0.003509
# Fnlwgt               -0.014802       -0.059368 -0.008028
# Education             0.061926        0.068106  0.077595
# Education_num         0.160676        0.054546  0.337713
# Marital_status       -0.197365       -0.017388 -0.198368
# Occupation           -0.019913       -0.003726  0.034469
# Relationship         -0.263261       -0.010985 -0.251538
# Race                  0.045423        0.122124  0.072482
# Sex                   0.238823        0.002136  0.216675
# Hours_per_week        1.000000        0.004622  0.242334
# Native_country        0.004622        1.000000  0.017675
# Income                0.242334        0.017675  1.000000

# %% [markdown]
# **Visualizing the correlation matrix by plotting heat map.**

# %%
plt.figure(figsize=(25,15))
sns.heatmap(df_new.corr(),linewidths=.1,vmin=-1, vmax=1, fmt='.1g', annot = True, linecolor="black",annot_kws={'size':10},cmap="coolwarm")
plt.yticks(rotation=0);

# %% [markdown]
# **Observations:**
#
# 1. Workclass and Fnlwgt has very less correlation with target variable.
#
# 2. Native_country, Occupation, Race and Education has less correlation with target variable.
#
# 3. Education and Education_num are corelated but not very high

# %%
cor['Income'].sort_values(ascending=False)
# Out:
# Income            1.000000
# Education_num     0.337713
# Age               0.248263
# Hours_per_week    0.242334
# Sex               0.216675
# Education         0.077595
# Race              0.072482
# Occupation        0.034469
# Native_country    0.017675
# Workclass         0.003509
# Fnlwgt           -0.008028
# Marital_status   -0.198368
# Relationship     -0.251538
# Name: Income, dtype: float64

# %% [markdown]
# As we can see here that Income is highly corelated with Education_num & Age

# %% [markdown]
# ### Visualizing the correlation between label and features

# %%
plt.figure(figsize=(20,10))
df_new.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar',color='b')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Workclass and Fnlwgt is very less correlated with target column.

# %% [markdown]
# ### Separating features and label

# %%
x = df.drop("Income", axis=1)
y = df["Income"]

# %%
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          5   83311          8             13               2
# 1       38          3  215646         10              9               0
# 2       53          3  234721          1              7               2
# 3       28          3  338409          8             13               2
# 4       37          3  284582         11             14               2
# ...    ...        ...     ...        ...            ...             ...
# 32555   27          3  257302          6             12               2
# 32556   40          3  154374         10              9               2
# 32557   58          3  151910         10              9               6
# 32558   22          3  201490         10              9               4
# 32559   52          4  287927         10              9               2
#
#        Occupation  Relationship  Race  Sex  Hours_per_week  Native_country
# 0               3             0     4    1              13              38
# 1               5             1     4    1              40              38
# 2               5             0     2    1              40              38
# 3               9             5     2    0              40               4
# 4               3             5     4    0              40              38
# ...           ...           ...   ...  ...             ...             ...
# 32555          12             5     4    0              38              38
# 32556           6             0     4    1              40              38
# 32557           0             4     4    0              40              38
# 32558           0             3     4    1              20              38
# 32559           3             5     4    0              40              38
#
# [31440 rows x 12 columns]

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32555    0
# 32556    1
# 32557    0
# 32558    0
# 32559    1
# Name: Income, Length: 31440, dtype: int32

# %%
x.shape
# Out:
# (31440, 12)

# %%
y.shape
# Out:
# (31440,)

# %% [markdown]
# ### Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.874695   1.722237 -1.077607  -0.348082       1.154149
# 1     -0.025698  -0.080414  0.324098   0.246006      -0.459837
# 2      1.099794  -0.080414  0.526142  -2.427393      -1.266831
# 3     -0.776026  -0.080414  1.624415  -0.348082       1.154149
# 4     -0.100731  -0.080414  1.054274   0.543051       1.557646
# ...         ...        ...       ...        ...            ...
# 31435 -0.851059  -0.080414  0.765322  -0.942171       0.750653
# 31436  0.124367  -0.080414 -0.324901   0.246006      -0.459837
# 31437  1.474957  -0.080414 -0.351000   0.246006      -0.459837
# 31438 -1.226223  -0.080414  0.174156   0.246006      -0.459837
# 31439  1.024761   0.820911  1.089705   0.246006      -0.459837
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.403322   -0.784437     -0.903164  0.391351  0.706601
# 1           -1.732719   -0.282484     -0.282023  0.391351  0.706601
# 2           -0.403322   -0.282484     -0.903164 -1.969371  0.706601
# 3           -0.403322    0.721421      2.202542 -1.969371 -1.415226
# 4           -0.403322   -0.784437      2.202542  0.391351 -1.415226
# ...               ...         ...           ...       ...       ...
# 31435       -0.403322    1.474351      2.202542  0.391351 -1.415226
# 31436       -0.403322   -0.031508     -0.903164  0.391351  0.706601
# 31437        2.255471   -1.537366      1.581401  0.391351 -1.415226
# 31438        0.926075   -1.537366      0.960260  0.391351  0.706601
# 31439       -0.403322   -0.784437      2.202542  0.391351 -1.415226
#
#        Hours_per_week  Native_country
# 0           -2.425021        0.254034
# 1           -0.008690        0.254034
# 2           -0.008690        0.254034
# 3           -0.008690       -5.456609
# 4           -0.008690        0.254034
# ...               ...             ...
# 31435       -0.187678        0.254034
# 31436       -0.008690        0.254034
# 31437       -0.008690        0.254034
# 31438       -1.798565        0.254034
# 31439       -0.008690        0.254034
#
# [31440 rows x 12 columns]

# %% [markdown]
# We have scaled the data using standard scalarization method to overcome the issue of biasness we have use standard scaler which will convert dataset into mean=0 and std=1
#
# Now we check for the multicolinearity for this we use Variance Inflation factor(VIF) method

# %% [markdown]
# ### Checking for multicolinearity

# %%
# Find Varience Inflation Factor (VIF) in each scaled column above.

from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd


vif = pd.DataFrame()

vif['VIF values'] = [variance_inflation_factor(x.values, i)
              for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#     VIF values        Features
# 0     1.165522             Age
# 1     1.008236       Workclass
# 2     1.011822          Fnlwgt
# 3     1.156545       Education
# 4     1.194536   Education_num
# 5     1.137977  Marital_status
# 6     1.016506      Occupation
# 7     1.686946    Relationship
# 8     1.033481            Race
# 9     1.562996             Sex
# 10    1.138685  Hours_per_week
# 11    1.024163  Native_country

# %% [markdown]
# if vif value is greater than 10 than we can say that multicolinearity is present in the dataset but here we can see that vif value for each of the columns is less than 10 so multicolinearirty is not present in the dataset. so there is no multicolinearity present in the dataset.

# %% [markdown]
# ### Oversampling method for balancing of the data set

# %%
#Checking value count of target column
y.value_counts()
# Out:
# 0    23834
# 1     7606
# Name: Income, dtype: int64

# %%
#oversampling the data
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %%
#Checking value count of target column
y.value_counts()
# Out:
# 0    23834
# 1    23834
# Name: Income, dtype: int64

# %% [markdown]
# Here we can see that both 0 & 1 has equal number of values we use this to prevent the biaseness in the dataset

# %% [markdown]
# ## Modeling
#
# ### Finding Best Random State and Accuracy:

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.ensemble import RandomForestClassifier
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state =i)
    mod = RandomForestClassifier()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8870708342073981  on Random_state  18

# %% [markdown]
# ### Creating train_test split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)

# %% [markdown]
# ### Importing Classification Algorithms

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score

# %% [markdown]
# ### DecisionTree Classifier

# %%
#checking accuracy for DecisionTreeclassifier
DTC=DecisionTreeClassifier()
DTC.fit(x_train, y_train)
predDTC=DTC.predict(x_test)
print('Accuracy Score',accuracy_score(y_test, predDTC))
print('Confusion Matrix',confusion_matrix(y_test, predDTC))
print('Classification Report',classification_report(y_test,predDTC))
# Out:
# Accuracy Score 0.8312006153415845
# Confusion Matrix [[5890 1248]
#  [1166 5997]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83      7138
#            1       0.83      0.84      0.83      7163
#
#     accuracy                           0.83     14301
#    macro avg       0.83      0.83      0.83     14301
# weighted avg       0.83      0.83      0.83     14301

# %%
cm = confusion_matrix(y_test, predDTC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f") 
plt.title('Confusion Matrix for Decision Tree Classifier')
plt.show()

# %% [markdown]
# ### RandomForestClassifier

# %%
RFC=RandomForestClassifier()
RFC.fit(x_train, y_train)
predRFC=RFC.predict(x_test)
print('Accuracy Score:',accuracy_score(y_test, predRFC))
print('Confusion Matrix:',confusion_matrix(y_test, predRFC))
print(classification_report(y_test,predRFC))
# Out:
# Accuracy Score: 0.8860918816865954
# Confusion Matrix: [[6183  955]
#  [ 674 6489]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.87      0.88      7138
#            1       0.87      0.91      0.89      7163
#
#     accuracy                           0.89     14301
#    macro avg       0.89      0.89      0.89     14301
# weighted avg       0.89      0.89      0.89     14301

# %%
cm = confusion_matrix(y_test, predRFC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", cmap="Purples") 
plt.title('Confusion Matrix for Random Forest Classifier')
plt.show()

# %% [markdown]
# ### SupportVectorClassifier

# %%
#checking accuracy for support vector machine classifier

svc=SVC()
svc.fit(x_train,y_train)
predsvc= svc.predict(x_test)
print('Accuracy Score', accuracy_score(y_test,predsvc))
print('Confusion Matrix', confusion_matrix(y_test,predsvc))
print('Classification Report', classification_report(y_test,predsvc))
# Out:
# Accuracy Score 0.8261660023774561
# Confusion Matrix [[5416 1722]
#  [ 764 6399]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.88      0.76      0.81      7138
#            1       0.79      0.89      0.84      7163
#
#     accuracy                           0.83     14301
#    macro avg       0.83      0.83      0.83     14301
# weighted avg       0.83      0.83      0.83     14301

# %%
cm = confusion_matrix(y_test, predsvc)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f") 
plt.title('Confusion Matrix for Support Vector Classifier')
plt.show()

# %% [markdown]
# ### K-Neighbor Classifier

# %%
#checking accuracy for support k-Neighbors classifier

KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
predKNN= KNN.predict(x_test)
print('Accuracy Score', accuracy_score(y_test,predKNN))
print('Confusion Matrix', confusion_matrix(y_test,predKNN))
print('Classification Report', classification_report(y_test,predKNN))
# Out:
# Accuracy Score 0.8419690930704147
# Confusion Matrix [[5413 1725]
#  [ 535 6628]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.91      0.76      0.83      7138
#            1       0.79      0.93      0.85      7163
#
#     accuracy                           0.84     14301
#    macro avg       0.85      0.84      0.84     14301
# weighted avg       0.85      0.84      0.84     14301

# %%
cm = confusion_matrix(y_test, predKNN)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", cmap="Purples") 
plt.title('Confusion Matrix for K-Neighbors Classifier')
plt.show()

# %% [markdown]
# ### Gradient Boosting Classifier

# %%
#checking accuracy for gradient boosting classifier
GB=GradientBoostingClassifier()
GB.fit(x_train,y_train)
predGB=GB.predict(x_test)
print('Accuracy Score', accuracy_score(y_test,predGB))
print('Confusion Matrix', confusion_matrix(y_test,predGB))
print('Classification Report', classification_report(y_test,predGB))
# Out:
# Accuracy Score 0.8558142787217677
# Confusion Matrix [[5804 1334]
#  [ 728 6435]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.89      0.81      0.85      7138
#            1       0.83      0.90      0.86      7163
#
#     accuracy                           0.86     14301
#    macro avg       0.86      0.86      0.86     14301
# weighted avg       0.86      0.86      0.86     14301

# %%
cm = confusion_matrix(y_test, predGB)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f") 
plt.title('Confusion Matrix for Gradient Boosting Classifier')
plt.show()

# %% [markdown]
# ### Logistic Regression

# %%
# Checking accuracy for Logistic Regression Classifier
LR = LogisticRegression()
LR.fit(x_train,y_train)

# Prediction
predLR = LR.predict(x_test)

print('Accuracy Score',accuracy_score(y_test, predLR))
print('Confusion Matrix',confusion_matrix(y_test, predLR))
print('Classification Report',classification_report(y_test,predLR))
# Out:
# Accuracy Score 0.7568002237605762
# Confusion Matrix [[5263 1875]
#  [1603 5560]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.77      0.74      0.75      7138
#            1       0.75      0.78      0.76      7163
#
#     accuracy                           0.76     14301
#    macro avg       0.76      0.76      0.76     14301
# weighted avg       0.76      0.76      0.76     14301

# %%
cm = confusion_matrix(y_test, predLR)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f", cmap="Purples") 
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# ### AdaBoost Classifier

# %%
#checking accuracy for AdaBoost Classifier
ABC=AdaBoostClassifier()
ABC.fit(x_train, y_train)
predABC=ABC.predict(x_test)
print('Accuracy Score', accuracy_score(y_test,predABC))
print('Confusion Matrix', confusion_matrix(y_test,predABC))
print('Classification Report', classification_report(y_test,predABC))
# Out:
# Accuracy Score 0.8402908887490386
# Confusion Matrix [[5711 1427]
#  [ 857 6306]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83      7138
#            1       0.82      0.88      0.85      7163
#
#     accuracy                           0.84     14301
#    macro avg       0.84      0.84      0.84     14301
# weighted avg       0.84      0.84      0.84     14301

# %%
cm = confusion_matrix(y_test, predABC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f",cmap="Purples" ) 
plt.title('Confusion Matrix for AdaBoost Classifier')
plt.show()

# %% [markdown]
# ### Bagging Classifier

# %%
#checking accuracy for Bagging classifier

BC=BaggingClassifier()
BC.fit(x_train,y_train)
predBC= BC.predict(x_test)
print('Accuracy Score', accuracy_score(y_test,predBC))
print('Confusion Matrix', confusion_matrix(y_test,predBC))
print('Classification Report', classification_report(y_test,predBC))
# Out:
# Accuracy Score 0.8637857492483043
# Confusion Matrix [[6177  961]
#  [ 987 6176]]
# Classification Report               precision    recall  f1-score   support
#
#            0       0.86      0.87      0.86      7138
#            1       0.87      0.86      0.86      7163
#
#     accuracy                           0.86     14301
#    macro avg       0.86      0.86      0.86     14301
# weighted avg       0.86      0.86      0.86     14301

# %%
cm = confusion_matrix(y_test, predBC)
sns.heatmap(cm, annot = True, linewidths=0.2, linecolor="black", fmt = ".0f" ) 
plt.title('Confusion Matrix for AdaBoost Classifier')
plt.show()

# %% [markdown]
# ### Cross-validation score

# %%
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

# Predict using logistic regression
pred_lr = LR.predict(x_test)

# Calculate the accuracy score
lss = accuracy_score(y_test, pred_lr)

# Perform cross-validation for different folds
for j in range(2, 15):
    # Calculate cross-validation scores
    cv_scores = cross_val_score(LR, x, y, cv=j)
    mean_cv_score = cv_scores.mean()
    
    # Display the results
    print('At cv:', j)
    print('Cross-validation score is:', mean_cv_score * 100)
    print('Accuracy score is:', lss * 100)
    print('\n')
# Out:
# At cv: 2
# Cross-validation score is: 75.10489217084837
# Accuracy score is: 75.68002237605762
#
#
# At cv: 3
# Cross-validation score is: 75.06923827265415
# Accuracy score is: 75.68002237605762
#
#
# At cv: 4
# Cross-validation score is: 75.10069648401443
# Accuracy score is: 75.68002237605762
#
#
# At cv: 5
# Cross-validation score is: 75.08183523604568
# Accuracy score is: 75.68002237605762
#
#
# At cv: 6
# Cross-validation score is: 75.0755495622705
# Accuracy score is: 75.68002237605762
#
#
# At cv: 7
# Cross-validation score is: 75.09653171620391
# Accuracy score is: 75.68002237605762
#
#
# At cv: 8
# Cross-validation score is: 75.08185831896724
# Accuracy score is: 75.68002237605762
#
#
# At cv: 9
# Cross-validation score is: 75.07557504190652
# Accuracy score is: 75.68002237605762
#
#
# At cv: 10
# Cross-validation score is: 75.09443332478563
# Accuracy score is: 75.68002237605762
#
#
# At cv: 11
# Cross-validation score is: 75.0797779685345
# Accuracy score is: 75.68002237605762
#
#
# At cv: 12
# Cross-validation score is: 75.0965421639707
# Accuracy score is: 75.68002237605762
#
#
# At cv: 13
# Cross-validation score is: 75.07766538980931
# Accuracy score is: 75.68002237605762
#
#
# At cv: 14
# Cross-validation score is: 75.09652263147764
# Accuracy score is: 75.68002237605762

# %% [markdown]
# ### CV for Logistic Regression

# %%
#using k-fold cross validation for Logistic Regression 
cvscore=cross_val_score(LR,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predLR) - cvscore.mean()))
# Out:
# [0.73358506 0.74910845 0.75435284 0.74512272 0.74826935 0.75687015
#  0.7478498  0.75791903 0.76877885 0.74758708]
# 0.7509443332478563
# Difference between Accuracy score and cross validation score is - 0.005855890512719952

# %% [markdown]
# ### CV for DecisionTreeClassifier

# %%
#using k-fold cross validation for decision tree classifier 
cvscore=cross_val_score(DTC,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predDTC) - cvscore.mean()))
# Out:
# [0.74659115 0.75770925 0.74952801 0.85126914 0.87119782 0.88189637
#  0.87644221 0.87518355 0.8701217  0.87704574]
# 0.8356984931285087
# Difference between Accuracy score and cross validation score is - 0.0044978777869242315

# %% [markdown]
# ### CV for SupportVectorClassifier

# %%
#using k-fold cross validation for support vector classifier 
cvscore=cross_val_score(svc,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predsvc) - cvscore.mean()))
# Out:
# [0.81120201 0.80742605 0.8147682  0.81665618 0.82190057 0.83259912
#  0.823369   0.82483742 0.83885858 0.82228284]
# 0.8213899966733456
# Difference between Accuracy score and cross validation score is - 0.00477600570411052

# %% [markdown]
# ### CV for k-Neighbour Classifier

# %%
#using k-fold cross validation for k-Neighbour classifier 
cvscore=cross_val_score(KNN,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predKNN) - cvscore.mean()))
# Out:
# [0.823369   0.8258863  0.83134047 0.84602475 0.85441578 0.86700231
#  0.86133837 0.86238725 0.86676458 0.85858162]
# 0.8497110414558898
# Difference between Accuracy score and cross validation score is - 0.00774194838547515

# %% [markdown]
# ### CV for RandomForestClassifier

# %%
#using k-fold cross validation for Random Forest classifier 
cvscore=cross_val_score(RFC,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predRFC) - cvscore.mean()))
# Out:
# [0.8053283  0.80595763 0.81707573 0.89720999 0.91944619 0.92657856
#  0.92699811 0.92406125 0.92362568 0.91775073]
# 0.8864032174620575
# Difference between Accuracy score and cross validation score is - 0.0003113357754621626

# %% [markdown]
# ### CV for GradientBoosting Classifier

# %%
#using k-fold cross validation for Gradient Boosting classifier 
cvscore=cross_val_score(GB,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predGB) - cvscore.mean()))
# Out:
# [0.80092301 0.80511852 0.80784561 0.85714286 0.86700231 0.87602266
#  0.874764   0.87665198 0.87893412 0.86760386]
# 0.8512008923427175
# Difference between Accuracy score and cross validation score is - 0.004613386379050288

# %% [markdown]
# ### CV for Adaboost classifier

# %%
#using k-fold cross validation for Adaboost classifier 
cvscore=cross_val_score(ABC,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predABC) - cvscore.mean()))
# Out:
# [0.80218167 0.79882526 0.80658695 0.84602475 0.8464443  0.8550451
#  0.85210824 0.85357667 0.84851028 0.83948804]
# 0.8348791272985409
# Difference between Accuracy score and cross validation score is - 0.00541176145049771

# %% [markdown]
# ### CV for Bagging classifier

# %%
#using k-fold cross validation for Bagging classifier 
cvscore=cross_val_score(BC,x,y,cv=10)
print(cvscore)
print(cvscore.mean())
print('Difference between Accuracy score and cross validation score is -',abs(accuracy_score(y_test,predBC) - cvscore.mean()))
# Out:
# [0.77344242 0.77742815 0.77973568 0.8842039  0.90727921 0.91462136
#  0.9133627  0.91483113 0.90579102 0.90432228]
# 0.867501785468902
# Difference between Accuracy score and cross validation score is - 0.003716036220597685

# %% [markdown]
# ### Selection for the final model

# %% [markdown]
# After trying different different classification model here we reach at the conclusion that `RandomForestClassifier` is our final model because when we have applied the RandomForestClassifier we got an `accuracy of 0.8870009090273407` and to over come overfitting and underfitting issue we use cross validation and get `cross validation score of 0.8859627284412058` and we find Difference between Accuracy score and cross validation score that is equal to 0.001038180586134918. so we select that model as our final model which has higher accuracy score and higher cross validation score and has lowest difference between between accuracy score and cross validation score. here `RandomForestClassifier` fullfills all our requriment so we select RandomForestClassifier as our final model

# %% [markdown]
# ### RandomForestClassifier as our final model

# %% [markdown]
# ### Hyperparameter Tuning for RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV

parameter = {'criterion':['gini','entropy'],
             'max_depth': [10,15,20,25],
             'n_estimators':[100,200,300,400],
             'max_features': ["auto","sqrt","log2"]}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter, cv=10)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'n_estimators': [100, 200, 300, 400]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 25,
#  'max_features': 'sqrt',
#  'n_estimators': 400}

# %% [markdown]
# ### Final Model

# %%
# Define and train the RandomForestClassifier
final_model = RandomForestClassifier(criterion='entropy', max_depth=25, n_estimators=400, max_features='sqrt')
final_model.fit(x_train, y_train)

# Make predictions
pred = final_model.predict(x_test)

# Calculate and print the accuracy score
accuracy = accuracy_score(y_test, pred)
print('Accuracy:', accuracy * 100)
# Out:
# Accuracy: 88.53926298860219

# %% [markdown]
# ### Auc-Roc curve

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

# %%
y_pred_prob=final_model.predict_proba(x_test)[:,1]
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
roc_auc=auc(fpr,tpr)

plt.plot([0,1],[0,1], 'k--')
plt.plot(fpr,tpr)
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()
auc_score=roc_auc_score(y_test, final_model.predict(x_test))
print('Auc score:' '\n', auc_score)
# Out:
# Auc score:
#  0.8853337273394492

# %%
# Plotting for all the models used here
from sklearn import datasets 
from sklearn import metrics
from sklearn import model_selection
from sklearn.metrics import plot_roc_curve 


disp = plot_roc_curve(KNN,x_test,y_test)
plot_roc_curve(DTC, x_test, y_test, ax=disp.ax_)     # ax_=Axes with confusion matrix
plot_roc_curve(RFC, x_test, y_test, ax=disp.ax_)
plot_roc_curve(LR, x_test, y_test, ax=disp.ax_)
plot_roc_curve(svc, x_test, y_test, ax=disp.ax_)
plot_roc_curve(GB, x_test, y_test, ax=disp.ax_)
plot_roc_curve(ABC, x_test, y_test, ax=disp.ax_)

plt.legend(prop={'size':11}, loc='lower right')
plt.show()

# %% [markdown]
# ### Saving best model

# %%
import joblib

joblib.dump(final_model, 'census_income_project.pkl')
# Out:
# ['census_income_project.pkl']

# %% [markdown]
# ### Predicting save model

# %%
model=joblib.load('census_income_project.pkl')

#Predict

prediction = model.predict(x_test)

prediction
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
pd.DataFrame([model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"]).T
# Out:
#        Predicted  Original
# 0              1         0
# 1              0         0
# 2              1         1
# 3              1         1
# 4              1         1
# ...          ...       ...
# 14296          0         0
# 14297          0         0
# 14298          1         1
# 14299          0         0
# 14300          0         0
#
# [14301 rows x 2 columns]

# %% [markdown]
# ### Conclusion
#
# Here we can see that the predicted values and original values are almost similiar so our model is working fine. RandomForestClassifier is wroking very well here

# %% [markdown]
# ## END OF THE PROJECT
